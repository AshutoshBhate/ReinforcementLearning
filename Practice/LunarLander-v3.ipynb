# %%
import gymnasium as gym
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
env_name = "LunarLander-v3"
env = gym.make(env_name, render_mode = None)

env = Monitor(env)
env = DummyVecEnv([lambda: env])

env.reset()

print("Observation Space Shape : ", env.observation_space.shape)
print("Sample Observation : ", env.observation_space.sample())
# Out:
# Observation Space Shape :  (8,)
# Sample Observation :  [-2.1709743   0.06801224 -2.3974411  -3.3341873   2.7114687   5.796174
#   0.03589563  0.9623087 ]
# c:\Users\ashut\anaconda3\envs\PbRL_env\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
print("Action Space Shape : ", env.action_space.n)
print("Action Space Sample : ", env.action_space.sample())
# Out:
# Action Space Shape :  4
# Action Space Sample :  3

# %%
model = PPO(
    policy = "MlpPolicy", 
    env = env, 
    n_steps = 1024, 
    batch_size = 64, 
    n_epochs = 4, 
    gamma = 0.999, 
    gae_lambda = 0.98, 
    ent_coef = 0.01, 
    verbose = 1, 
    device = "cpu"
)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps= 500000)

model_name = "ppo-LunarLander-v3"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.1     |
# |    ep_rew_mean     | -134     |
# | time/              |          |
# |    fps             | 872      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.7         |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0019183599 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00256      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 3.08e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.2        |
# |    ep_rew_mean          | -166        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.001483462 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000918   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67e+03    |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 3.53e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.6          |
# |    ep_rew_mean          | -167          |
# | time/                   |               |
# |    fps                  | 472           |
# |    iterations           | 4             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00019043777 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00268      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.14e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.000926     |
# |    value_loss           | 1.14e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 93.8          |
# |    ep_rew_mean          | -165          |
# | time/                   |               |
# |    fps                  | 472           |
# |    iterations           | 5             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00047004648 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00621      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.96e+03      |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.00182      |
# |    value_loss           | 6.37e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.6         |
# |    ep_rew_mean          | -167         |
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0002624368 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0166      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 4.29e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 97.9          |
# |    ep_rew_mean          | -162          |
# | time/                   |               |
# |    fps                  | 478           |
# |    iterations           | 7             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 0.00068152655 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.055        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.52e+03      |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.00257      |
# |    value_loss           | 4.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.9          |
# |    ep_rew_mean          | -160          |
# | time/                   |               |
# |    fps                  | 483           |
# |    iterations           | 8             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00057078514 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.0176       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 785           |
# |    n_updates            | 28            |
# |    policy_gradient_loss | -0.000992     |
# |    value_loss           | 2.4e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 97.4          |
# |    ep_rew_mean          | -158          |
# | time/                   |               |
# |    fps                  | 488           |
# |    iterations           | 9             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00022774457 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0187       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.32e+03      |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.000828     |
# |    value_loss           | 4.21e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.2         |
# |    ep_rew_mean          | -161         |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 10           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0004728288 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00369     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+03      |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 3.18e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.7         |
# |    ep_rew_mean          | -160         |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 11           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0005104154 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00132     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 2.51e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -163         |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 12           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0002953395 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0235      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+03      |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.0009      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 101           |
# |    ep_rew_mean          | -155          |
# | time/                   |               |
# |    fps                  | 531           |
# |    iterations           | 13            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 0.00061677943 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.00188      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 808           |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.00149      |
# |    value_loss           | 2.35e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -153         |
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 14           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0025901552 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00076     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+03     |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00418     |
# |    value_loss           | 2.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -155         |
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 15           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0009624356 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000329    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28e+03     |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 2.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -153         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 16           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0023880582 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0182      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00485     |
# |    value_loss           | 5.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 17           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 8.962379e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00218     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83e+03     |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00017     |
# |    value_loss           | 4.16e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | -153         |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 18           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0032442193 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00148     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 951          |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 1.93e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -152         |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 19           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0026715077 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000231    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28e+03     |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00511     |
# |    value_loss           | 3.07e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 107           |
# |    ep_rew_mean          | -152          |
# | time/                   |               |
# |    fps                  | 576           |
# |    iterations           | 20            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00067481364 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.000461     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 577           |
# |    n_updates            | 76            |
# |    policy_gradient_loss | -0.00167      |
# |    value_loss           | 1.24e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -151         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 21           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0010390442 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00523     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 748          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 1.51e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -140         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 22           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0017825072 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.0175      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 624          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00323     |
# |    value_loss           | 1.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | -134         |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 23           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0036600064 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000679     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 658          |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 1.12e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 108           |
# |    ep_rew_mean          | -132          |
# | time/                   |               |
# |    fps                  | 585           |
# |    iterations           | 24            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00093276124 |
# |    clip_fraction        | 0.00146       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.000761     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 473           |
# |    n_updates            | 92            |
# |    policy_gradient_loss | -0.00209      |
# |    value_loss           | 1.14e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 25          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.004427045 |
# |    clip_fraction        | 0.000732    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0063     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 1.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 26          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011124695 |
# |    clip_fraction        | 0.0286      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.000109    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 678         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 27          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.003732673 |
# |    clip_fraction        | 0.00317     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.000991   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 412         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 28          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.002774974 |
# |    clip_fraction        | 0.000244    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00143    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 215         |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 557         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 29          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.008272864 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.000867   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 278         |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 650         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | -99.7        |
# | time/                   |              |
# |    fps                  | 648          |
# |    iterations           | 30           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0007470179 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.000956    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 710          |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 1.25e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | -94          |
# | time/                   |              |
# |    fps                  | 656          |
# |    iterations           | 31           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0058694007 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.00871     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 320          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 777          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -92.8       |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 32          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010324562 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.000398   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 298         |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00835    |
# |    value_loss           | 602         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -93.6       |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 33          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.009666254 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.000438   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 149         |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 318         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 120          |
# |    ep_rew_mean          | -90.8        |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 34           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0035420626 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.00413     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 310          |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 990          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -91.2       |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 35          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009347046 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.000462   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 220         |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 333         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | -90.1        |
# | time/                   |              |
# |    fps                  | 690          |
# |    iterations           | 36           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0044265897 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -0.00112     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 291          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00583     |
# |    value_loss           | 668          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | -85.8        |
# | time/                   |              |
# |    fps                  | 695          |
# |    iterations           | 37           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0069525316 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.000693    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 212          |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 669          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | -85.5       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 38          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006469954 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.000135   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 186         |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 375         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | -84.5       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 39          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.005358885 |
# |    clip_fraction        | 0.00757     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.000193   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 238         |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 557         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | -83.1        |
# | time/                   |              |
# |    fps                  | 713          |
# |    iterations           | 40           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0076657184 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.000344    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 269          |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00944     |
# |    value_loss           | 597          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | -81.3       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 41          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.007752779 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.000415   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 188         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 426         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | -78         |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 42          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006378358 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.00049    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 300         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | -72.9        |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 43           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0025904728 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.000108    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 100          |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 290          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 149        |
# |    ep_rew_mean          | -69.8      |
# | time/                   |            |
# |    fps                  | 733        |
# |    iterations           | 44         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00866075 |
# |    clip_fraction        | 0.052      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | -0.000175  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 175        |
# |    n_updates            | 172        |
# |    policy_gradient_loss | -0.00493   |
# |    value_loss           | 353        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -68.4       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 45          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.010664362 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -9.99e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.00375    |
# |    value_loss           | 315         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | -66.6        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 46           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0030628233 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.000548     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 118          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 374          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | -64.6       |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 47          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.006567642 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.00013    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 210         |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 786         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | -63.6        |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 48           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0054044523 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00191     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.000963    |
# |    value_loss           | 373          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 186           |
# |    ep_rew_mean          | -61.7         |
# | time/                   |               |
# |    fps                  | 751           |
# |    iterations           | 49            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 50176         |
# | train/                  |               |
# |    approx_kl            | 0.00024858653 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.27         |
# |    explained_variance   | 0.00125       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 233           |
# |    n_updates            | 192           |
# |    policy_gradient_loss | -0.000736     |
# |    value_loss           | 438           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 188          |
# |    ep_rew_mean          | -60.3        |
# | time/                   |              |
# |    fps                  | 755          |
# |    iterations           | 50           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0018218991 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.00998      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 134          |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 189          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | -61         |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 51          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.010927615 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.000789    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 356         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 804         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 194           |
# |    ep_rew_mean          | -61.5         |
# | time/                   |               |
# |    fps                  | 763           |
# |    iterations           | 52            |
# |    time_elapsed         | 69            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00013756508 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.12         |
# |    explained_variance   | -0.000391     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 262           |
# |    n_updates            | 204           |
# |    policy_gradient_loss | -0.000511     |
# |    value_loss           | 729           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 196           |
# |    ep_rew_mean          | -66.2         |
# | time/                   |               |
# |    fps                  | 766           |
# |    iterations           | 53            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 54272         |
# | train/                  |               |
# |    approx_kl            | 0.00015627214 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.13         |
# |    explained_variance   | 0.0153        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 498           |
# |    n_updates            | 208           |
# |    policy_gradient_loss | -0.000524     |
# |    value_loss           | 761           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 196           |
# |    ep_rew_mean          | -67.5         |
# | time/                   |               |
# |    fps                  | 770           |
# |    iterations           | 54            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00011314842 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00484       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 542           |
# |    n_updates            | 212           |
# |    policy_gradient_loss | -0.000518     |
# ...
# |    ep_rew_mean          | 86.3         |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 472          |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0075723664 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.25         |
# |    n_updates            | 1884         |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 23.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | 84.4         |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 473          |
# |    time_elapsed         | 528          |
# |    total_timesteps      | 484352       |
# | train/                  |              |
# |    approx_kl            | 0.0059180004 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.965       |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 1888         |
# |    policy_gradient_loss | -0.00339     |
# |    value_loss           | 150          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | 84.6         |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 474          |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0016101736 |
# |    clip_fraction        | 0.00464      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.2         |
# |    n_updates            | 1892         |
# |    policy_gradient_loss | -0.000146    |
# |    value_loss           | 265          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 746        |
# |    ep_rew_mean          | 82.8       |
# | time/                   |            |
# |    fps                  | 916        |
# |    iterations           | 475        |
# |    time_elapsed         | 530        |
# |    total_timesteps      | 486400     |
# | train/                  |            |
# |    approx_kl            | 0.00839258 |
# |    clip_fraction        | 0.0574     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.757     |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.52       |
# |    n_updates            | 1896       |
# |    policy_gradient_loss | -0.00514   |
# |    value_loss           | 18.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | 83           |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 476          |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0014775179 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.889       |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 141          |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.000829    |
# |    value_loss           | 265          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | 82.8         |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 477          |
# |    time_elapsed         | 532          |
# |    total_timesteps      | 488448       |
# | train/                  |              |
# |    approx_kl            | 0.0059793903 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 1904         |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 33.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 751          |
# |    ep_rew_mean          | 81.8         |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 478          |
# |    time_elapsed         | 533          |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0064227637 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98           |
# |    n_updates            | 1908         |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 125          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 759          |
# |    ep_rew_mean          | 82.7         |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 479          |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 490496       |
# | train/                  |              |
# |    approx_kl            | 0.0076651163 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.1         |
# |    n_updates            | 1912         |
# |    policy_gradient_loss | -0.000353    |
# |    value_loss           | 41.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 759          |
# |    ep_rew_mean          | 82.4         |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 480          |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0036738059 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99         |
# |    n_updates            | 1916         |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 20.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 754          |
# |    ep_rew_mean          | 83.7         |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 481          |
# |    time_elapsed         | 536          |
# |    total_timesteps      | 492544       |
# | train/                  |              |
# |    approx_kl            | 0.0010475711 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.891       |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.3         |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -1.88e-05    |
# |    value_loss           | 28           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | 83.9        |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 482         |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.010583112 |
# |    clip_fraction        | 0.0286      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.9        |
# |    n_updates            | 1924        |
# |    policy_gradient_loss | 0.000606    |
# |    value_loss           | 309         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | 83.6        |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 483         |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 494592      |
# | train/                  |             |
# |    approx_kl            | 0.013645494 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.12        |
# |    n_updates            | 1928        |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 19          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 740        |
# |    ep_rew_mean          | 81.4       |
# | time/                   |            |
# |    fps                  | 918        |
# |    iterations           | 484        |
# |    time_elapsed         | 539        |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.00498441 |
# |    clip_fraction        | 0.0237     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.965     |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.21       |
# |    n_updates            | 1932       |
# |    policy_gradient_loss | 0.00124    |
# |    value_loss           | 7.54       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 734          |
# |    ep_rew_mean          | 79.7         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 485          |
# |    time_elapsed         | 540          |
# |    total_timesteps      | 496640       |
# | train/                  |              |
# |    approx_kl            | 0.0017721676 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 168          |
# |    n_updates            | 1936         |
# |    policy_gradient_loss | -0.000663    |
# |    value_loss           | 363          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 738          |
# |    ep_rew_mean          | 79.1         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 486          |
# |    time_elapsed         | 541          |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0010840194 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.9         |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | 2.44e-05     |
# |    value_loss           | 117          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 737          |
# |    ep_rew_mean          | 78.9         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 487          |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 498688       |
# | train/                  |              |
# |    approx_kl            | 0.0021039406 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.961       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.89         |
# |    n_updates            | 1944         |
# |    policy_gradient_loss | 0.00033      |
# |    value_loss           | 13           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 742          |
# |    ep_rew_mean          | 76.4         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 488          |
# |    time_elapsed         | 544          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0030840128 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.93        |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 1948         |
# |    policy_gradient_loss | 0.000294     |
# |    value_loss           | 192          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | 78.1        |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 489         |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 500736      |
# | train/                  |             |
# |    approx_kl            | 0.004262482 |
# |    clip_fraction        | 0.00806     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 1952        |
# |    policy_gradient_loss | -0.0028     |
# |    value_loss           | 148         |
# -----------------------------------------

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
#Evaluation : 

model = PPO.load("ppo-LunarLander-v3.zip")

eval_env = Monitor(gym.make("LunarLander-v3"))

print("Evaluating model quality")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# c:\Users\ashut\anaconda3\envs\PbRL_env\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Evaluating model quality
# Mean Reward: 32.52 +/- 116.69

# %%
env = gym.make("LunarLander-v3", render_mode = "human")

print("Random Agent : Before Training")

obs, _ = env.reset()
for i in range (300):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    
    if terminated or truncated:
        obs, _ = env.reset()

env.close()
# Out:
# Random Agent : Before Training

# %%
import pygame

env = gym.make("LunarLander-v3", render_mode = "human")

print("Random Agent : After Training")

obs, _ = env.reset()

try:
    while True:
        
        for event in pygame.event.get():
            
            # If user presses a key
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_ESCAPE:
                    raise KeyboardInterrupt
                
        action, _ = model.predict(obs, deterministic=True)
        
        obs, reward, terminated, truncated, info = env.step(action)
        
        if terminated or truncated:
            print("Landed! Resetting")
            obs, _ = env.reset()
            
except KeyboardInterrupt:
    print("\nClosing Environment")
    env.close()
# Out:
# Random Agent : After Training
#
# Closing Environment
